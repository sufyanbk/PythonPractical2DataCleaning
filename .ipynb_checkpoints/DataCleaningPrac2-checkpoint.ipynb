# %% [markdown]
# # Introduction to the Practical
#
# In this practical, we will demonstrate how to investigate, clean, and prepare a dataset, along with a analysing the complexity of algorithms. This is to ensure the data is accurate, consistentm and ready for any further analysis or modelling.
#
# We are limited to the libraries that can be utilised to conduct the data analysis hence the following libraries will be used:
#
# 1. numpy (np) - This is for numerical operations and handling arrays etc.
# 2. time - This is to track the execution track of algorithms and assess their time complexity.
# 3. os - This is to interact with the operating system, especially to check memory usage or file sizes.
# 4. garbage collection (gc) - This is to manage the memory usage and clean objects that are no longer in use.
# 5. pandas (pd) - This is for data manipulation and analysis.
# 6. psutil - This is to monitor system resources like CPU and memory being used.
#
# We will also be utilising GIT as version control where code will be regularly committed and maintain. All git logs will be attachec with the submission.

# %% [markdown]
# ## Stage 1 - Importing required Libraries and loading the data set

# %% [markdown]
# Import the libraries:

# %%
import pandas as pd
import numpy as np
import time
import gc
import psutil
import os

# %% [markdown]
# Load the Dataset

# %%
# Defining the dataset file path
dataset_filepath = 'dataset.csv'

# Load the data set now as a pandas frame
data = pd.read_csv(dataset_filepath, header=None)

# Displaying the first 5 rows to see if the data is being shown successfully
data.head()
# Out:
#                                         0
# 0   Level\tT4\tT3\tT3adjusted\tT4adjusted
# 1    5\t8.1\t2.1\t2.00829885\t1.280579165
# 2                 5\t8.7\t\t2.056710116\t
# 3  10\t3.5\t1.6\t1.518294486\t1.169607095
# 4  20\t7.9\t4.6\t1.991631701\t1.663103499

# %% [markdown]
# ### Stage 2 - Data Cleaning
# In this section we are going to focus on cleaning the data set.

# %%
# Cleaning up the file 
# Split based on the tab character '\t' This will split each row into a seperate column wherever a tab is encountered.
# It essentially treats the file as a single column at first then splits it into multiple columns
data_cleaned = data[0].str.split('\t', expand=True)

# Assign column names from the first row and remove the header row from the data
data_cleaned.columns = data_cleaned.iloc[0] # Assign first row of the data as the actual column headers
data_cleaned = data_cleaned.drop(0).reset_index(drop=True)

# Convert relevant columns to numeric. The data once split is in string format, to perform statistical operations etc we need to ensure its numeric
data_cleaned = data_cleaned.apply(pd.to_numeric)

# Display the cleaned dataframe to inspect if the data is being shown as expected
data_cleaned.head()
# Out:
# 0  Level   T4   T3  T3adjusted  T4adjusted
# 0      5  8.1  2.1    2.008299    1.280579
# 1      5  8.7  NaN    2.056710         NaN
# 2     10  3.5  1.6    1.518294    1.169607
# 3     20  7.9  4.6    1.991632    1.663103
# 4     30  2.3  0.4    1.320006    0.736806

# %% [markdown]
# ### Stage 3 - Handling Missing Values Case
# In this section we will idenitfy and replace any missing values in columns T3 and T4 using average values specific to their level

# %%
# Replacing Missing Values in T3 and T4 with Mean Values Grouped by 'Level'

# Drop rows where 'Level' is missing or non-numeric (if applicable)
data_cleaned = data_cleaned[data_cleaned['Level'].notnull()]
data_cleaned['Level'] = pd.to_numeric(data_cleaned['Level'], errors='coerce')

# Remove rows where 'Level' is still NaN (if any) after conversion
data_cleaned = data_cleaned.dropna(subset=['Level'])


# Fill missing values in T3 and T4 with group means based on the 'Level' column
data_cleaned['T3'] = data_cleaned.groupby('Level')['T3'].transform(lambda x: x.fillna(x.mean()))
data_cleaned['T4'] = data_cleaned.groupby('Level')['T4'].transform(lambda x: x.fillna(x.mean()))

# Display the cleaned data to verify that missing values have been filled
data_cleaned.head()
# Out:
# 0  Level   T4        T3  T3adjusted  T4adjusted
# 0      5  8.1  2.100000    2.008299    1.280579
# 1      5  8.7  4.029113    2.056710         NaN
# 2     10  3.5  1.600000    1.518294    1.169607
# 3     20  7.9  4.600000    1.991632    1.663103
# 4     30  2.3  0.400000    1.320006    0.736806

# %% [markdown]
# We have been able to replace missing values in T3 and T4 with mean values grouped by their specific level.

# %% [markdown]
# ### Stage 4 - Descriptive Statistics
# We will be calulating basic descriptive statistics for each column.

# %%
# Calculating Descriptive statistics manually

def descriptive_statistics(df):
    statistics = pd.DataFrame({
        'Sum': df.sum(),
        'Mean': df.mean(),
        'Median': df.median(),
        'Mode': df.mode().iloc[0],  # Mode might return multiple values, so we take the first one
        'StdDev': df.std(),
        'Variance': df.var(),
        'Range': df.max() - df.min(),
        'Min': df.min(),
        'Max': df.max(),
        'Unique Values': df.nunique()  # Count of unique values
    })
    return statistics

# %% [markdown]
# We are utilising an array of different statistics to allow a more comprehensive analysis of the data set.
# The statistics that are used are as follows:
# 1. **Sum** - The total sum of all values in the column
# 2. **Mean** - The avergae of all values in the column
# 3. **Median** - The middle value in the sorted list of all values
# 4. **Mode** - The most frequently occuring value
# 5. **StdDev** - A measure of how spread out the values are. This quantifies the variation in the data. A higher STDev means data is more spread out from the average and vice versa.
# 6. **Variance** - The square of the StdDev, this gives an actual value to how much the numbers vary from the average of all values.
# 7. **Range** - The difference between the maximum and the minimum value
# 8. **Min** - The smallest value in the data set
# 9. **Max** - The largest value in the data set
# 10. **Unique Values** - The number of distinct values present in the data set

# %%
# Lets compute the statistics for our data

manual_statistics = descriptive_statistics(data_cleaned)

manual_statistics
# Out:
#                      Sum       Mean     Median       Mode     StdDev  \
# 0
# Level       15605.000000  32.375519  20.000000  20.000000  58.158773
# T4           7402.319873  15.357510  11.241357  12.454915  19.757047
# T3           6115.748987  12.688276   8.200000   4.029113  14.923203
# T3adjusted    962.530045   2.022122   2.217399   0.000000   1.274283
# T4adjusted    701.413786   1.890603   2.000000   0.000000   1.245630
#
#                Variance       Range        Min         Max  Unique Values
# 0
# Level       3382.442892  395.000000   5.000000  400.000000             14
# T4           390.340903  279.600000 -44.400000  235.200000            396
# T3           222.701975  186.800000 -38.400000  148.400000            314
# T3adjusted     1.623798    9.713770  -3.541014    6.172756            392
# T4adjusted     1.551593    8.668064  -3.373731    5.294334            306

# %% [markdown]
# ### Stage 5 - Compare manual statistics to pandas.describe()
# We will compare the manually calulcated stats to the ones automatically generated by pandas.descrive func

# %%
# Calculate descriptive statistics using pandas.describe()
pandas_stats = data_cleaned.describe()

# Display both the manually calculated stats and the pandas.describe() results
print("Manually Calculated Descriptive Statistics:")
print(manual_statistics)

print("\nDescriptive Statistics from pandas.describe():")
print(pandas_stats)
# Out:
# Manually Calculated Descriptive Statistics:
#                      Sum       Mean     Median       Mode     StdDev  \
# 0
# Level       15605.000000  32.375519  20.000000  20.000000  58.158773
# T4           7402.319873  15.357510  11.241357  12.454915  19.757047
# T3           6115.748987  12.688276   8.200000   4.029113  14.923203
# T3adjusted    962.530045   2.022122   2.217399   0.000000   1.274283
# T4adjusted    701.413786   1.890603   2.000000   0.000000   1.245630
#
#                Variance       Range        Min         Max  Unique Values
# 0
# Level       3382.442892  395.000000   5.000000  400.000000             14
# T4           390.340903  279.600000 -44.400000  235.200000            396
# T3           222.701975  186.800000 -38.400000  148.400000            314
# T3adjusted     1.623798    9.713770  -3.541014    6.172756            392
# T4adjusted     1.551593    8.668064  -3.373731    5.294334            306
#
# Descriptive Statistics from pandas.describe():
# ...

# %% [markdown]
# We have now successfully comapred our results with the pandas.describe()

# %% [markdown]
# ### Step 6 - Identify any repeated rows and confirmation
# Lets write logic to identify any repeated code and confirmation if there are none

# %%
# Check for duplicates
duplicates = data_cleaned[data_cleaned.duplicated()]

# Display duplicates (if any)
duplicates
# Out:
# 0    Level         T4         T3  T3adjusted  T4adjusted
# 120     20  14.700000  17.169391    2.449660         NaN
# 206     40  18.416388  20.410854         NaN         NaN
# 252      5  18.400000  12.100000    2.640012    2.295770
# 274     10  19.800000  11.400000    2.705339    2.250617
# 334     15  31.000000  13.193684    3.141381         NaN
# 359     20  19.500000  15.600000    2.691606    2.498666
# 466    200  12.000000  17.783333    2.289428         NaN
# 467    200  16.300000  37.300000    2.535494    3.341204
# 468    100  27.800000  42.300000    3.029342    3.484283
# 469    200  12.900000   9.000000    2.345290    2.080084
# 470    100  19.100000  17.800000    2.673075    2.610999
# 472    300   0.000000   0.000000    0.000000    0.000000
# 474    400   0.600000   1.800000    0.843433    1.216440
# 475    300   6.900000   8.000000    1.903778    2.000000
# 477    150 -13.600000  -4.500000   -2.386966   -1.650964
# ...

# %% [markdown]
# ## Stage 2 - Time and Space complexity
#
# In this notebook, we will investigate the time and space complexity of three different operations:
# 1. Standard matrix multiplication.
# 2. Use of an inefficient sort.
# 3. Comparing Pythons find() with a custom loop-based method to find substrings.

# %% [markdown]
# Lets start with imports

# %%
import matplotlib.pyplot as plt # We need to install this as this may not be installed prior - Use command pip

# %% [markdown]
# Operation 1: Matrix Multiplication
# 1. Generate random matrices that increase in size and then multiply them to np.dot method.
# 2. We will be recording the time and space required as this method is executed.

# %%
def matrix_multiplication(size):
    A = np.random.randint(0, 500, (size, size))
    B = np.random.randint(0, 500, (size, size))
    return np.dot(A, B)

# %% [markdown]
# Lets measure the time and space complexity of the matrix multiplication

# %%
def measure_complexity(func, sizes):
    process = psutil.Process(os.getpid()) # Get the current process
    base_ram = process.memory_info().rss
    # Init lists to store results for space and time
    res_space = [] 
    res_time = []

    # Loop through each sizes parameter
    for size in sizes:
        gc.collect()
        
        start = time.time() # Record start time
        func(size)
        end = time.time() # Record the end time
        
        ram = process.memory_info().rss # Store the memory usage
        
        res_time.append(end - start) # Calculate the time for the function execution
        res_space.append(ram - base_ram) # Calculate the time for the function execution
    
    return res_time, res_space

# %% [markdown]
# Now let's utilise scattor plots to visualise the results
# - The x acis will represent size
# - The y axis will represent time (s) and space (byte)

# %%
def plot_complexity(input_sizes, execution_time, memory_usage, graph_title):

    fig, primary_axis = plt.subplots()

    primary_axis.set_xlabel('Size') # X label
    primary_axis.set_ylabel('Time (s)', color='tab:red') # Y label
    
    # Create a scatter plot
    primary_axis.scatter(input_sizes, execution_time, color='tab:red', label='Time')

    primary_axis.tick_params(axis='y', labelcolor='tab:red')

    secondary_axis = primary_axis.twinx()     # Create a secondary y-axis for memory usage

    secondary_axis.set_ylabel('Space (bytes)', color='tab:blue') # Y label

    
    # Create a scatter plot for memory usage
    secondary_axis.scatter(input_sizes, memory_usage, color='tab:blue', label='Space')
    

    secondary_axis.tick_params(axis='y', labelcolor='tab:blue')

    fig.tight_layout()
 
    plt.title(graph_title)    # Set the title of the plot

    plt.show()

# %%
# Now lets run the matrix manipulation analysis:

input_sizes = [10, 50, 100, 1000, 10000]          # Example sizes
execution_time = [0.001, 0.01, 0.1, 1, 10]      # Example execution times in seconds
memory_usage = [100, 200, 300, 400, 500]        # Example memory usage in bytes
graph_title = "Complexity Visualisation"         # Title of the plot

# Call the function with the example data
plot_complexity(input_sizes, execution_time, memory_usage, graph_title)

# %% [markdown]
# Operation 2: Inefficeint Integer Sorting
# 1. We will sort an unordered list of integers using an inefficient algorithm selection sort
# 2. We will be recording the time and space required as this method is executed.

# %%
def inefficient_sort(arr):

    sorted_array = []     # Create an empty list to hold the sorted values
    
    # Continue until the original array is empty
    while arr:
        # Find the minimum value in the current array
        min_value = min(arr)
        
        # Add the minimum value to the sorted array
        sorted_array.append(min_value)
        
        # Remove the minimum value from the original array
        arr.remove(min_value)
    
    return sorted_array

# %%
# Lets run the inefficient sorting algorithm:
sizes = [1000, 2000, 3000, 4000, 5000]
res_time, res_space = measure_complexity(lambda size: inefficient_sort(list(np.random.randint(0, 1000, size))), sizes)
plot_complexity(sizes, res_time, res_space, "Inefficient Sorting Complexity")

# %% [markdown]
# Operation 3: Substring Search
#
# For this we will compare Pythons find() with a loop based substring search to determine which is more efficient

# %%
def locate_substring(main_string, target_substring):
    target_length = len(target_substring) # Calculate the target substring length
    
    for index in range(len(main_string)):
        # Check if the substring can fit starting from the current index & compare the slice of the main string with the target one
        if main_string[index:index + target_length] == target_substring:
            return index # if a math is found return the starting index
    return -1

# %%
# Legend Breakdown:
# Red Circle: Execution time for the custom search.
# Orange Circle: Execution time for the built-in find().
# Blue Circle: Memory usage for the custom search.
# Green Circle: Memory usage for the built-in find().

# String sizes for testing the substring search functions
string_sizes = [10000, 50000, 100000, 200000, 500000]  
search_substring = 'findme'

# Measure performance for the custom substring  function
execution_time_custom, memory_usage_custom = measure_complexity(lambda size: locate_substring('a' * size, search_substring), string_sizes)

# Measure performance for Python's built-in find() method
execution_time_builtin, memory_usage_builtin = measure_complexity(lambda size: ('a' * size).find(search_substring), string_sizes)

# Function to visualise the comparison between the two methods
def display_comparison(sizes, time_custom, time_builtin, space_custom, space_builtin):
    fig, main_axis = plt.subplots()

    main_axis.set_xlabel('String Size')  # Label for the X axis
    main_axis.set_ylabel('Execution Time (s)', color='tab:red')  # Label for the primary Y axis

    # Plotting the execution time comparison
    main_axis.scatter(sizes, time_custom, color='tab:red', label='Custom Search Time')
    main_axis.scatter(sizes, time_builtin, color='tab:orange', label="Built-in find() Time")
    main_axis.tick_params(axis='y', labelcolor='tab:red')

    # Creating a secondary Y axis for memory usage
    secondary_axis = main_axis.twinx()  
    secondary_axis.set_ylabel('Memory Usage (bytes)', color='tab:blue')  # Label for the secondary Y axis

    # Plotting the memory usage comparison
    secondary_axis.scatter(sizes, space_custom, color='tab:blue', label='Custom Search Space')
    secondary_axis.scatter(sizes, space_builtin, color='tab:green', label="Built-in find() Space")
    secondary_axis.tick_params(axis='y', labelcolor='tab:blue')

    fig.tight_layout()
    plt.title("Comparison of Custom Search vs Built-in find() Complexity") 
    plt.show()

# Calling the function to display the comparison of both execution time and memory usage
display_comparison(string_sizes, execution_time_custom, execution_time_builtin, memory_usage_custom, memory_usage_builtin)

# %% [markdown]
# ## Conclusion
# In this notebook, we:
# - Cleaned and transformed a tab-separated dataset.
# - Replaced missing values with group-level averages.
# - Calculated descriptive statistics manually.
# - Compared our manually generated statistics with pandas.describe() ones
# - Checked for duplicate rows in the data.
#
# - Explored the time and space complexity of matrix multiplication, inefficient sort algorithm and substring search using two methods.
# - We have visualised and displayed how both the time and space grows as the size of the problem increases.
# - This has helped us understand the computational costs of these operations.
